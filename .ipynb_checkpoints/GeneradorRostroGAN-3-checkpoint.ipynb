# %% [markdown]
# # Generador de rostros artificiales mediante redes adversativas

# %% [markdown]
# En este se usara imagenes de menor tamaño (128x128 -> 32x32 )
#
# En una red adversaria se tienen dos modelos (que pueden ser Redes Neuronales o Convolucionales) compitiendo: un Generador y un Discriminador.
#
# Se genera un primer modelo que llamaremos Discriminador para que sea capaz de reconocer rostros humanos. Este discriminador será simplemente un clasificador,que buscara indicar si una imagen es real o falsa
#
# Se genera un segundo modelo, que llamaremos Generador y nuestro objetivo es entrenarlo para que sea capaz de tomar una entrada aleatoria y a la salida generar algo muy parecido a una imagen de un rostro.
#
# La idea es entrenar esos dos modelos simultáneamente buscando que al final sea el Generador el vencedor en esta competencia.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from keras.preprocessing.image import img_to_array

# %% [markdown]
# ### Funcion para carga y visualizar datos

# %%
def cargar_datos(dataset, TAM_IMG):
    print('Creando set de entrenamiento...')
    filelist = os.listdir(dataset)

    n_imgs = len(filelist)
    x_train = np.zeros((n_imgs,TAM_IMG,TAM_IMG,3))

    for i in range(n_imgs):
        direcion = str(dataset)+ "\\" + str(filelist[i])
        imagen = cv2.imread(direcion,1)
        imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
        imagen = cv2.resize(imagen, dsize=(TAM_IMG, TAM_IMG))
        imagen = (imagen - 127.5)/127.5 #para dejarlo entre -1 y 1
        x_train[i,:] = imagen
    print('¡Listo!')

    return x_train

def visualizar_imagen(imagen):
    imagen = imagen * 0.5 + 0.5 #para pasarlo de 0 a 1
    plt.imshow(imagen)
    plt.show()

# %% [markdown]
# ### Funcion para la creacion de los modelos

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Reshape, Conv2DTranspose, BatchNormalization, Conv2D, LeakyReLU, Flatten, Input, UpSampling2D
from keras.layers.core import Activation

# %%
def crear_generador(TAM_ENTRADA, TAM_IMG):
    modelo = Sequential(name = "Generador")
    
    modelo.add(Dense(4*4*3, use_bias=False, input_shape=(TAM_ENTRADA,)))
    modelo.add(Reshape((4,4,3)))
    #Tamaño resultante: 4x4x3
    
    modelo.add(Conv2DTranspose(128, 2, strides=1,padding='same',kernel_initializer='he_normal',use_bias=False))
    #Tamaño resultante: 4x4x128
    
    modelo.add(Conv2DTranspose(64, 4, strides=2,padding='same',kernel_initializer='he_normal',use_bias=False))
    #modelo.add(Conv2DTranspose(64, 2, strides=1,padding='same',kernel_initializer='he_normal',use_bias=False))
    modelo.add(BatchNormalization())
    #Tamaño resultante: 8x8x64
    
    modelo.add(Conv2DTranspose(32, 4, strides=2,padding='same',kernel_initializer='he_normal',use_bias=False))
    #modelo.add(Conv2DTranspose(32, 2, strides=1,padding='same',kernel_initializer='he_normal',use_bias=False))
    modelo.add(BatchNormalization())
    #Tamaño resultante: 16x16x32
    
    modelo.add(Conv2DTranspose(16, 4, strides=2,padding='same',kernel_initializer='he_normal',use_bias=False))
    #modelo.add(Conv2DTranspose(16, 2, strides=1,padding='same',kernel_initializer='he_normal',use_bias=False))
    modelo.add(BatchNormalization())
    #Tamaño resultante: 32x32x16
    
    modelo.add(Conv2D(3, 2, strides = 1, padding='same',kernel_initializer='he_normal',use_bias=False))
    modelo.add(Conv2D(3, 2, strides = 1, padding='same',kernel_initializer='he_normal',use_bias=False))
    modelo.add(Conv2D(3, 2, strides = 1, padding = 'same',activation = 'tanh'))
    #Tamaño resultante: 32x32x3
    
    #modelo.compile(optimizer="Adam", loss="binary_crossentropy")

    return modelo

# %%
def crear_discriminador(TAM_IMG):
    
    modelo = Sequential(name = "Discriminador")

    modelo.add(Conv2D(32, 4, strides=2, padding='same',kernel_initializer='he_normal', input_shape=(TAM_IMG,TAM_IMG,3)))
    modelo.add(BatchNormalization())
    modelo.add(LeakyReLU())
    #16x16x32

    modelo.add(Conv2D(64, 4, strides=2, padding='same',kernel_initializer='he_normal'))
    modelo.add(BatchNormalization())
    modelo.add(LeakyReLU())
    #8x8x64
    
    modelo.add(Conv2D(128, 4, strides=1, padding='same',kernel_initializer='he_normal'))
    modelo.add(BatchNormalization())
    modelo.add(LeakyReLU())
    #4x4x128
    
    modelo.add(Flatten())
    modelo.add(Dense(100, activation='LeakyReLU'))
    modelo.add(Dense(1, activation='sigmoid'))

    modelo.compile(optimizer="Adam", loss="binary_crossentropy")

    return modelo

# %%
def crear_GAN(generador, discriminador):
    modelo = Sequential(name = "GAN")
    modelo.add(generador)
    discriminador.trainable = False
    modelo.add(discriminador)
    modelo.compile(optimizer="Adam", loss="binary_crossentropy")

    return modelo

# %% [markdown]
# ### Carga de datos y creacion de modelos

# %%
TAM_ENTRADA = 100
TAM_IMG = 32

# %%
x_train = cargar_datos("dataset1", TAM_IMG)
# Out:
# Creando set de entrenamiento...
# ¡Listo!

# %%
visualizar_imagen(x_train[12])

# %%
generador = crear_generador(TAM_ENTRADA, TAM_IMG)
# generador.summary()
print("")
print("")
discriminador = crear_discriminador(TAM_IMG)
# discriminador.summary()
print("")
print("")
gan = crear_GAN(generador, discriminador)
# gan.summary()

# %% [markdown]
# ### Entrenamiento

# %% [markdown]
# En el caso de las Redes Adversarias debemos llevar a cabo estos pasos:
#
# 1. “Descongelar” los coeficientes del Discriminador
# 2. Entrenar solo el Discriminador con imagenes falsas y reales
# 3. “Congelar” los coeficientes del Discriminador
# 4. Entrenar la GAN, al estar congelado el discriminador únicamente se entrenara el Generador
# 5. Repetir los pasos 1 a 4 por el número de iteraciones que se vayan a usar el entrenamiento

# %%
TAM_LOTE = 150 
N_ITS = 5000
import time

# %%
prediccion_falsa = np.array([])
error_d_acumulado = np.array([])

for i in range(1,N_ITS+1):
    start = time.time()
    print("Comenzando Epoca " + str(i), end = "")

    # Crear un "batch" de imágenes falsas y otro con imágenes reales
    ruido = np.random.normal(0,1,[TAM_LOTE,TAM_ENTRADA])
    batch_falsas = generador.predict(ruido)
    
    idx = np.random.randint(low=0, high=x_train.shape[0],size=TAM_LOTE)
    batch_reales = x_train[idx]
    
    #la unificacion del batch de entrenamiento es lo que logra que el modelo aprenda
    batch = np.concatenate(( batch_reales, batch_falsas))
    valores = np.concatenate((np.ones(TAM_LOTE)*0.9, np.zeros(TAM_LOTE)))
    
    print(".", end = "")
    
    # Entrenar discriminador con imagener falsas y reales, y en cada
    # caso calcular el error
    discriminador.trainable = True

    #las reales le digo como resultado 1 con np.ones
    #las falsas le digo como resultado 0 con np.zeros
    #dError_reales = discriminador.train_on_batch(batch_reales, np.ones(TAM_LOTE)*0.9) #El 0.9 ayuda a que converga mejor
    #dError_falsas = discriminador.train_on_batch(batch_falsas, np.zeros(TAM_LOTE))
    
    dError = discriminador.train_on_batch(batch, valores)
    
    error_d_acumulado = np.append(error_d_acumulado, dError)
    
    #congelo el discriminador
    discriminador.trainable = False

    print(".", end = "")
    
    # Entrenar GAN: se generará ruido aleatorio y se presentará a la GAN
    # como si fuesen imagenes reales
    ruido = np.random.normal(0,1,[TAM_LOTE,TAM_ENTRADA])
    gError = gan.train_on_batch(ruido, np.ones(TAM_LOTE))
    
    print(".", end = "")
    
    #Cada 100 iteraciones vamos a guardar una imagen
    if i==1 or i%100 == 0:
        ruido = np.random.normal(0,1,TAM_ENTRADA)
        ruido = np.array([ruido])
        resultado = generador.predict(ruido)
        resultado = resultado * 0.5 + 0.5
        plt.imshow(resultado.reshape(TAM_IMG,TAM_IMG,3))
        plt.savefig("resultadosGAN-3/r"+ str(i) + ".png")
    
    ruido = np.random.normal(0,1,TAM_ENTRADA)
    ruido = np.array([ruido])
    resultado = generador.predict(ruido)
    
    ppp = discriminador(resultado)
    prediccion_falsa = np.append(prediccion_falsa, ppp)
    end = time.time()
    print(" Fin")
    print("Tiempo transcurrido: ",end - start)
    print("prediccion de ruido: ",ppp)
    print("===================================================================")
# Out:
# Comenzando Epoca 1... Fin
# Tiempo transcurrido:  2.663485288619995
# prediccion de ruido:  tf.Tensor([[0.168636]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 2... Fin
# Tiempo transcurrido:  0.7498414516448975
# prediccion de ruido:  tf.Tensor([[0.10192609]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3... Fin
# Tiempo transcurrido:  0.7962400913238525
# prediccion de ruido:  tf.Tensor([[0.79596996]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 4... Fin
# Tiempo transcurrido:  0.7862462997436523
# prediccion de ruido:  tf.Tensor([[0.15298235]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 5... Fin
# Tiempo transcurrido:  0.7530097961425781
# prediccion de ruido:  tf.Tensor([[0.14461547]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 6... Fin
# Tiempo transcurrido:  0.7692229747772217
# prediccion de ruido:  tf.Tensor([[0.34661266]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 7... Fin
# Tiempo transcurrido:  0.8142712116241455
# prediccion de ruido:  tf.Tensor([[0.54769397]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 8... Fin
# Tiempo transcurrido:  0.8120520114898682
# prediccion de ruido:  tf.Tensor([[0.6351117]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 9... Fin
# Tiempo transcurrido:  0.7486224174499512
# prediccion de ruido:  tf.Tensor([[0.04415542]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 10... Fin
# Tiempo transcurrido:  0.7874362468719482
# prediccion de ruido:  tf.Tensor([[0.07487822]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 11... Fin
# Tiempo transcurrido:  0.7848522663116455
# prediccion de ruido:  tf.Tensor([[0.03771597]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 12... Fin
# Tiempo transcurrido:  0.7692301273345947
# prediccion de ruido:  tf.Tensor([[0.24923062]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 13... Fin
# Tiempo transcurrido:  0.7858302593231201
# prediccion de ruido:  tf.Tensor([[0.10371283]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 14... Fin
# Tiempo transcurrido:  0.7846114635467529
# prediccion de ruido:  tf.Tensor([[0.05554768]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 15... Fin
# Tiempo transcurrido:  0.7710115909576416
# prediccion de ruido:  tf.Tensor([[0.09019563]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 16... Fin
# Tiempo transcurrido:  0.7850127220153809
# prediccion de ruido:  tf.Tensor([[0.00144488]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 17... Fin
# Tiempo transcurrido:  0.7704126834869385
# prediccion de ruido:  tf.Tensor([[0.0277274]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 18... Fin
# Tiempo transcurrido:  0.7850127220153809
# prediccion de ruido:  tf.Tensor([[0.03770924]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 19... Fin
# Tiempo transcurrido:  0.7736320495605469
# prediccion de ruido:  tf.Tensor([[0.05115354]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 20... Fin
# Tiempo transcurrido:  0.8148188591003418
# prediccion de ruido:  tf.Tensor([[0.01925912]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 21... Fin
# Tiempo transcurrido:  0.7598276138305664
# prediccion de ruido:  tf.Tensor([[0.03614241]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 22... Fin
# Tiempo transcurrido:  0.7954518795013428
# prediccion de ruido:  tf.Tensor([[0.11905897]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 23... Fin
# Tiempo transcurrido:  0.7904658317565918
# prediccion de ruido:  tf.Tensor([[0.03883991]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 24... Fin
# Tiempo transcurrido:  0.7838156223297119
# prediccion de ruido:  tf.Tensor([[0.11808267]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 25... Fin
# Tiempo transcurrido:  0.766441822052002
# prediccion de ruido:  tf.Tensor([[0.04758015]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 26... Fin
# Tiempo transcurrido:  0.8380837440490723
# prediccion de ruido:  tf.Tensor([[0.01220509]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 27... Fin
# Tiempo transcurrido:  0.817241907119751
# prediccion de ruido:  tf.Tensor([[0.09535977]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 28... Fin
# Tiempo transcurrido:  0.8404490947723389
# prediccion de ruido:  tf.Tensor([[0.11022189]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 29... Fin
# Tiempo transcurrido:  0.8138771057128906
# prediccion de ruido:  tf.Tensor([[0.04017645]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 30... Fin
# Tiempo transcurrido:  0.8428652286529541
# prediccion de ruido:  tf.Tensor([[0.05244601]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 31... Fin
# Tiempo transcurrido:  0.840857982635498
# prediccion de ruido:  tf.Tensor([[0.26638663]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 32... Fin
# Tiempo transcurrido:  0.8918554782867432
# prediccion de ruido:  tf.Tensor([[0.09410599]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 33... Fin
# Tiempo transcurrido:  0.890841007232666
# prediccion de ruido:  tf.Tensor([[0.00617835]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 34... Fin
# Tiempo transcurrido:  0.8108766078948975
# prediccion de ruido:  tf.Tensor([[0.05043635]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 35... Fin
# Tiempo transcurrido:  0.827476978302002
# prediccion de ruido:  tf.Tensor([[0.02847108]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 36... Fin
# Tiempo transcurrido:  0.8308422565460205
# prediccion de ruido:  tf.Tensor([[0.18599409]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 37... Fin
# Tiempo transcurrido:  0.9090836048126221
# prediccion de ruido:  tf.Tensor([[0.15548798]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 38... Fin
# Tiempo transcurrido:  0.9378745555877686
# prediccion de ruido:  tf.Tensor([[0.02069128]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 39... Fin
# Tiempo transcurrido:  0.8224692344665527
# prediccion de ruido:  tf.Tensor([[0.02135879]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 40... Fin
# Tiempo transcurrido:  0.8436610698699951
# prediccion de ruido:  tf.Tensor([[0.08587632]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 41... Fin
# Tiempo transcurrido:  0.771047830581665
# prediccion de ruido:  tf.Tensor([[0.04780567]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 42... Fin
# Tiempo transcurrido:  0.801058292388916
# prediccion de ruido:  tf.Tensor([[0.00590754]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 43... Fin
# Tiempo transcurrido:  0.7680110931396484
# prediccion de ruido:  tf.Tensor([[0.00101519]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 44... Fin
# Tiempo transcurrido:  0.7526154518127441
# prediccion de ruido:  tf.Tensor([[0.00357193]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 45... Fin
# Tiempo transcurrido:  0.7732160091400146
# prediccion de ruido:  tf.Tensor([[0.01957333]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 46... Fin
# Tiempo transcurrido:  0.749812126159668
# prediccion de ruido:  tf.Tensor([[0.00394619]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 47... Fin
# Tiempo transcurrido:  0.7694127559661865
# prediccion de ruido:  tf.Tensor([[0.00590754]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 48... Fin
# Tiempo transcurrido:  0.7692155838012695
# prediccion de ruido:  tf.Tensor([[0.00408342]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 49... Fin
# Tiempo transcurrido:  0.7692229747772217
# prediccion de ruido:  tf.Tensor([[0.00521594]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 50... Fin
# Tiempo transcurrido:  0.7526445388793945
# prediccion de ruido:  tf.Tensor([[0.00178882]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 51... Fin
# Tiempo transcurrido:  0.786815881729126
# prediccion de ruido:  tf.Tensor([[0.00741291]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 52... Fin
# Tiempo transcurrido:  0.8048615455627441
# prediccion de ruido:  tf.Tensor([[0.01132932]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 53... Fin
# Tiempo transcurrido:  0.7998464107513428
# prediccion de ruido:  tf.Tensor([[0.06384036]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 54... Fin
# Tiempo transcurrido:  0.7472426891326904
# prediccion de ruido:  tf.Tensor([[0.02079779]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 55... Fin
# Tiempo transcurrido:  0.7914440631866455
# prediccion de ruido:  tf.Tensor([[0.03068873]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 56... Fin
# Tiempo transcurrido:  0.7688140869140625
# prediccion de ruido:  tf.Tensor([[0.02468425]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 57... Fin
# Tiempo transcurrido:  0.7694127559661865
# prediccion de ruido:  tf.Tensor([[0.01227233]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 58... Fin
# Tiempo transcurrido:  0.7446436882019043
# prediccion de ruido:  tf.Tensor([[0.01335168]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 59... Fin
# Tiempo transcurrido:  0.7774209976196289
# prediccion de ruido:  tf.Tensor([[0.11778525]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 60... Fin
# Tiempo transcurrido:  0.7686095237731934
# prediccion de ruido:  tf.Tensor([[0.01920155]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 61... Fin
# Tiempo transcurrido:  0.7694127559661865
# prediccion de ruido:  tf.Tensor([[0.00742605]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 62... Fin
# Tiempo transcurrido:  0.7694125175476074
# prediccion de ruido:  tf.Tensor([[0.02355301]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 63... Fin
# Tiempo transcurrido:  0.7538125514984131
# prediccion de ruido:  tf.Tensor([[0.06976029]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 64... Fin
# Tiempo transcurrido:  0.7680113315582275
# prediccion de ruido:  tf.Tensor([[0.00705871]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 65... Fin
# Tiempo transcurrido:  0.7694125175476074
# prediccion de ruido:  tf.Tensor([[0.00639105]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 66... Fin
# Tiempo transcurrido:  0.7538127899169922
# prediccion de ruido:  tf.Tensor([[0.00432721]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 67... Fin
# Tiempo transcurrido:  0.7684123516082764
# prediccion de ruido:  tf.Tensor([[0.01428941]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 68... Fin
# Tiempo transcurrido:  0.7538127899169922
# prediccion de ruido:  tf.Tensor([[0.00768301]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 69... Fin
# Tiempo transcurrido:  0.7684123516082764
# prediccion de ruido:  tf.Tensor([[0.1106993]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 70... Fin
# Tiempo transcurrido:  0.8028395175933838
# prediccion de ruido:  tf.Tensor([[0.07649705]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 71... Fin
# Tiempo transcurrido:  0.7574188709259033
# prediccion de ruido:  tf.Tensor([[0.03795466]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 72... Fin
# Tiempo transcurrido:  0.7838449478149414
# prediccion de ruido:  tf.Tensor([[0.0901247]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 73... Fin
# Tiempo transcurrido:  0.7998242378234863
# prediccion de ruido:  tf.Tensor([[0.12187687]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 74... Fin
# Tiempo transcurrido:  0.7554333209991455
# prediccion de ruido:  tf.Tensor([[0.00239959]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 75... Fin
# Tiempo transcurrido:  0.7570464611053467
# prediccion de ruido:  tf.Tensor([[0.02505296]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 76... Fin
# Tiempo transcurrido:  0.8152639865875244
# prediccion de ruido:  tf.Tensor([[0.01064107]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 77... Fin
# Tiempo transcurrido:  0.8042337894439697
# prediccion de ruido:  tf.Tensor([[0.00147462]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 78... Fin
# Tiempo transcurrido:  0.7686169147491455
# prediccion de ruido:  tf.Tensor([[0.02277839]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 79... Fin
# Tiempo transcurrido:  0.7544183731079102
# prediccion de ruido:  tf.Tensor([[0.02013516]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 80... Fin
# Tiempo transcurrido:  0.7634122371673584
# prediccion de ruido:  tf.Tensor([[0.03983298]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 81... Fin
# Tiempo transcurrido:  0.7886629104614258
# prediccion de ruido:  tf.Tensor([[0.03506905]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 82... Fin
# Tiempo transcurrido:  0.7900497913360596
# prediccion de ruido:  tf.Tensor([[0.0086925]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 83... Fin
# Tiempo transcurrido:  0.8126504421234131
# prediccion de ruido:  tf.Tensor([[0.10514605]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 84... Fin
# Tiempo transcurrido:  0.7538125514984131
# prediccion de ruido:  tf.Tensor([[0.2435509]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 85... Fin
# Tiempo transcurrido:  0.7562437057495117
# prediccion de ruido:  tf.Tensor([[0.01944399]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 86... Fin
# Tiempo transcurrido:  0.7986345291137695
# prediccion de ruido:  tf.Tensor([[0.07179809]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 87... Fin
# Tiempo transcurrido:  0.7540314197540283
# prediccion de ruido:  tf.Tensor([[0.00902998]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 88... Fin
# Tiempo transcurrido:  0.7752525806427002
# prediccion de ruido:  tf.Tensor([[0.08193421]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 89... Fin
# Tiempo transcurrido:  0.7986490726470947
# prediccion de ruido:  tf.Tensor([[0.00903514]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 90... Fin
# Tiempo transcurrido:  0.802058219909668
# prediccion de ruido:  tf.Tensor([[0.00059792]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 91... Fin
# Tiempo transcurrido:  0.8402664661407471
# prediccion de ruido:  tf.Tensor([[0.00375131]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 92... Fin
# Tiempo transcurrido:  0.8394784927368164
# prediccion de ruido:  tf.Tensor([[0.03093731]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 93... Fin
# Tiempo transcurrido:  0.8228485584259033
# prediccion de ruido:  tf.Tensor([[0.00875756]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 94... Fin
# Tiempo transcurrido:  0.8076355457305908
# prediccion de ruido:  tf.Tensor([[0.00122082]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 95... Fin
# Tiempo transcurrido:  0.9058642387390137
# prediccion de ruido:  tf.Tensor([[0.03956464]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 96... Fin
# Tiempo transcurrido:  0.8134610652923584
# prediccion de ruido:  tf.Tensor([[0.01412791]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 97... Fin
# Tiempo transcurrido:  0.7916703224182129
# prediccion de ruido:  tf.Tensor([[0.00039613]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 98... Fin
# Tiempo transcurrido:  0.8530707359313965
# prediccion de ruido:  tf.Tensor([[0.00493819]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 99... Fin
# Tiempo transcurrido:  0.8230531215667725
# prediccion de ruido:  tf.Tensor([[0.13034806]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 100... Fin
# Tiempo transcurrido:  0.893643856048584
# prediccion de ruido:  tf.Tensor([[0.01814237]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 101... Fin
# Tiempo transcurrido:  0.8182425498962402
# prediccion de ruido:  tf.Tensor([[0.00189525]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 102... Fin
# Tiempo transcurrido:  0.7894368171691895
# prediccion de ruido:  tf.Tensor([[0.00257838]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 103... Fin
# Tiempo transcurrido:  0.7912688255310059
# prediccion de ruido:  tf.Tensor([[0.00123915]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 104... Fin
# Tiempo transcurrido:  0.779639720916748
# prediccion de ruido:  tf.Tensor([[0.00245035]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 105... Fin
# Tiempo transcurrido:  0.8026642799377441
# prediccion de ruido:  tf.Tensor([[0.00093499]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 106... Fin
# Tiempo transcurrido:  0.7704203128814697
# prediccion de ruido:  tf.Tensor([[0.04071194]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 107... Fin
# Tiempo transcurrido:  0.8012332916259766
# prediccion de ruido:  tf.Tensor([[0.02245861]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 108... Fin
# Tiempo transcurrido:  0.7594408988952637
# prediccion de ruido:  tf.Tensor([[0.01273128]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 109... Fin
# Tiempo transcurrido:  0.7886481285095215
# prediccion de ruido:  tf.Tensor([[0.00911412]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 110... Fin
# Tiempo transcurrido:  0.7990801334381104
# prediccion de ruido:  tf.Tensor([[0.04545394]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 111... Fin
# Tiempo transcurrido:  0.8022406101226807
# prediccion de ruido:  tf.Tensor([[0.02384263]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 112... Fin
# Tiempo transcurrido:  0.7650256156921387
# prediccion de ruido:  tf.Tensor([[0.009379]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 113... Fin
# Tiempo transcurrido:  0.7670106887817383
# prediccion de ruido:  tf.Tensor([[0.00153416]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 114... Fin
# Tiempo transcurrido:  0.7392129898071289
# prediccion de ruido:  tf.Tensor([[0.07022724]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 115... Fin
# Tiempo transcurrido:  0.7848155498504639
# prediccion de ruido:  tf.Tensor([[0.105441]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 116... Fin
# Tiempo transcurrido:  0.7670111656188965
# prediccion de ruido:  tf.Tensor([[0.01149914]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 117... Fin
# Tiempo transcurrido:  0.7708141803741455
# prediccion de ruido:  tf.Tensor([[0.02534017]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 118... Fin
# Tiempo transcurrido:  0.751812219619751
# prediccion de ruido:  tf.Tensor([[0.00144207]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 119... Fin
# Tiempo transcurrido:  0.8386533260345459
# prediccion de ruido:  tf.Tensor([[0.01390472]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 120... Fin
# Tiempo transcurrido:  0.8216443061828613
# prediccion de ruido:  tf.Tensor([[0.00744492]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 121... Fin
# Tiempo transcurrido:  0.7814357280731201
# prediccion de ruido:  tf.Tensor([[0.08655962]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 122... Fin
# Tiempo transcurrido:  0.7518124580383301
# prediccion de ruido:  tf.Tensor([[0.06156823]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 123... Fin
# Tiempo transcurrido:  0.7868449687957764
# prediccion de ruido:  tf.Tensor([[0.28482124]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 124... Fin
# Tiempo transcurrido:  0.7888453006744385
# prediccion de ruido:  tf.Tensor([[0.01142102]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 125... Fin
# Tiempo transcurrido:  0.7868232727050781
# prediccion de ruido:  tf.Tensor([[0.05987418]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 126... Fin
# Tiempo transcurrido:  0.7416141033172607
# prediccion de ruido:  tf.Tensor([[0.10128728]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 127... Fin
# Tiempo transcurrido:  0.7926559448242188
# prediccion de ruido:  tf.Tensor([[0.08450022]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 128... Fin
# Tiempo transcurrido:  0.8140814304351807
# prediccion de ruido:  tf.Tensor([[0.10373786]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 129... Fin
# Tiempo transcurrido:  0.876664400100708
# prediccion de ruido:  tf.Tensor([[0.00805432]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 130... Fin
# Tiempo transcurrido:  0.8396825790405273
# prediccion de ruido:  tf.Tensor([[0.05456167]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 131... Fin
# Tiempo transcurrido:  0.8756494522094727
# prediccion de ruido:  tf.Tensor([[0.25352037]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 132... Fin
# Tiempo transcurrido:  0.8112053871154785
# prediccion de ruido:  tf.Tensor([[0.1736818]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 133... Fin
# Tiempo transcurrido:  0.7800049781799316
# prediccion de ruido:  tf.Tensor([[0.08620787]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 134... Fin
# Tiempo transcurrido:  0.7488048076629639
# prediccion de ruido:  tf.Tensor([[0.23029196]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 135... Fin
# Tiempo transcurrido:  0.8268053531646729
# prediccion de ruido:  tf.Tensor([[0.12960422]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 136... Fin
# Tiempo transcurrido:  0.7488048076629639
# prediccion de ruido:  tf.Tensor([[0.04195413]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 137... Fin
# Tiempo transcurrido:  0.795604944229126
# prediccion de ruido:  tf.Tensor([[0.0588626]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 138... Fin
# Tiempo transcurrido:  0.7800052165985107
# prediccion de ruido:  tf.Tensor([[0.13452095]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 139... Fin
# Tiempo transcurrido:  0.7800047397613525
# prediccion de ruido:  tf.Tensor([[0.06344956]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 140... Fin
# Tiempo transcurrido:  0.774033784866333
# prediccion de ruido:  tf.Tensor([[0.02682966]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 141... Fin
# Tiempo transcurrido:  0.8150813579559326
# prediccion de ruido:  tf.Tensor([[0.02831692]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 142... Fin
# Tiempo transcurrido:  0.7868306636810303
# prediccion de ruido:  tf.Tensor([[0.16178629]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 143... Fin
# Tiempo transcurrido:  0.8072340488433838
# prediccion de ruido:  tf.Tensor([[0.23868522]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 144... Fin
# Tiempo transcurrido:  0.7532138824462891
# prediccion de ruido:  tf.Tensor([[0.03765759]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 145... Fin
# Tiempo transcurrido:  0.7690112590789795
# prediccion de ruido:  tf.Tensor([[0.01087332]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 146... Fin
# Tiempo transcurrido:  0.7708141803741455
# prediccion de ruido:  tf.Tensor([[0.14457193]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 147... Fin
# Tiempo transcurrido:  0.7518124580383301
# prediccion de ruido:  tf.Tensor([[0.15219903]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 148... Fin
# Tiempo transcurrido:  0.7694127559661865
# prediccion de ruido:  tf.Tensor([[0.25162303]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 149... Fin
# Tiempo transcurrido:  0.7686095237731934
# prediccion de ruido:  tf.Tensor([[0.11506942]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 150... Fin
# Tiempo transcurrido:  0.7704129219055176
# prediccion de ruido:  tf.Tensor([[0.06681097]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 151... Fin
# Tiempo transcurrido:  0.7670109272003174
# prediccion de ruido:  tf.Tensor([[0.10689175]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 152... Fin
# Tiempo transcurrido:  0.7562143802642822
# prediccion de ruido:  tf.Tensor([[0.03712031]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 153... Fin
# Tiempo transcurrido:  0.7670109272003174
# prediccion de ruido:  tf.Tensor([[0.00647125]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 154... Fin
# Tiempo transcurrido:  0.7714128494262695
# prediccion de ruido:  tf.Tensor([[0.14386621]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 155... Fin
# Tiempo transcurrido:  0.751410961151123
# prediccion de ruido:  tf.Tensor([[0.15415886]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 156... Fin
# Tiempo transcurrido:  0.7684125900268555
# prediccion de ruido:  tf.Tensor([[0.15533382]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 157... Fin
# Tiempo transcurrido:  0.7708141803741455
# prediccion de ruido:  tf.Tensor([[0.1644035]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 158... Fin
# Tiempo transcurrido:  0.7680113315582275
# prediccion de ruido:  tf.Tensor([[0.02959776]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 159... Fin
# Tiempo transcurrido:  0.7696096897125244
# prediccion de ruido:  tf.Tensor([[0.33377486]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 160... Fin
# Tiempo transcurrido:  0.7538127899169922
# prediccion de ruido:  tf.Tensor([[0.15206051]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 161... Fin
# Tiempo transcurrido:  0.7582216262817383
# prediccion de ruido:  tf.Tensor([[0.09102395]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 162... Fin
# Tiempo transcurrido:  0.8082704544067383
# prediccion de ruido:  tf.Tensor([[0.32765695]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 163... Fin
# Tiempo transcurrido:  0.7654051780700684
# prediccion de ruido:  tf.Tensor([[0.28176787]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 164... Fin
# Tiempo transcurrido:  0.8736057281494141
# prediccion de ruido:  tf.Tensor([[0.13731268]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 165... Fin
# Tiempo transcurrido:  0.7800047397613525
# prediccion de ruido:  tf.Tensor([[0.17778066]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 166... Fin
# Tiempo transcurrido:  0.7644050121307373
# prediccion de ruido:  tf.Tensor([[0.2618655]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 167... Fin
# Tiempo transcurrido:  0.7800049781799316
# prediccion de ruido:  tf.Tensor([[0.19214436]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 168... Fin
# Tiempo transcurrido:  0.7644047737121582
# prediccion de ruido:  tf.Tensor([[0.2676062]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 169... Fin
# Tiempo transcurrido:  0.7800049781799316
# prediccion de ruido:  tf.Tensor([[0.08041587]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 170... Fin
# Tiempo transcurrido:  0.7810053825378418
# prediccion de ruido:  tf.Tensor([[0.18210524]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 171... Fin
# Tiempo transcurrido:  0.7800047397613525
# prediccion de ruido:  tf.Tensor([[0.31754512]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 172... Fin
# Tiempo transcurrido:  0.7488048076629639
# prediccion de ruido:  tf.Tensor([[0.28769255]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 173... Fin
# Tiempo transcurrido:  0.7644047737121582
# prediccion de ruido:  tf.Tensor([[0.22531155]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 174... Fin
# Tiempo transcurrido:  0.7800052165985107
# prediccion de ruido:  tf.Tensor([[0.18991008]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 175... Fin
# Tiempo transcurrido:  0.7800049781799316
# prediccion de ruido:  tf.Tensor([[0.17039096]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 176... Fin
# Tiempo transcurrido:  0.7644047737121582
# prediccion de ruido:  tf.Tensor([[0.31956849]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 177... Fin
# Tiempo transcurrido:  0.748805046081543
# prediccion de ruido:  tf.Tensor([[0.1826798]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 178... Fin
# Tiempo transcurrido:  0.7800047397613525
# prediccion de ruido:  tf.Tensor([[0.08880991]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 179... Fin
# Tiempo transcurrido:  0.7956051826477051
# prediccion de ruido:  tf.Tensor([[0.22579882]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 180... Fin
# Tiempo transcurrido:  0.7664051055908203
# prediccion de ruido:  tf.Tensor([[0.30837017]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 181... Fin
# Tiempo transcurrido:  0.7644047737121582
# prediccion de ruido:  tf.Tensor([[0.27707624]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 182... Fin
# Tiempo transcurrido:  0.7654051780700684
# prediccion de ruido:  tf.Tensor([[0.11262634]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 183... Fin
# Tiempo transcurrido:  0.7644047737121582
# prediccion de ruido:  tf.Tensor([[0.28348735]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 184... Fin
# Tiempo transcurrido:  0.7654051780700684
# prediccion de ruido:  tf.Tensor([[0.4596209]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 185... Fin
# Tiempo transcurrido:  0.7644047737121582
# prediccion de ruido:  tf.Tensor([[0.18594792]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 186... Fin
# Tiempo transcurrido:  0.7664051055908203
# prediccion de ruido:  tf.Tensor([[0.25712538]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 187... Fin
# Tiempo transcurrido:  0.7644050121307373
# prediccion de ruido:  tf.Tensor([[0.2907033]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 188... Fin
# Tiempo transcurrido:  0.7800047397613525
# prediccion de ruido:  tf.Tensor([[0.29752165]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 189... Fin
# Tiempo transcurrido:  0.748805046081543
# prediccion de ruido:  tf.Tensor([[0.28952602]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 190... Fin
# Tiempo transcurrido:  0.7644050121307373
# prediccion de ruido:  tf.Tensor([[0.20000115]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 191... Fin
# Tiempo transcurrido:  0.7956051826477051
# prediccion de ruido:  tf.Tensor([[0.06986988]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 192... Fin
# Tiempo transcurrido:  0.7800049781799316
# prediccion de ruido:  tf.Tensor([[0.2594295]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 193... Fin
# Tiempo transcurrido:  0.795604944229126
# prediccion de ruido:  tf.Tensor([[0.4146762]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 194... Fin
# Tiempo transcurrido:  0.7644050121307373
# prediccion de ruido:  tf.Tensor([[0.25502527]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 195... Fin
# Tiempo transcurrido:  0.7644047737121582
# prediccion de ruido:  tf.Tensor([[0.1907095]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 196... Fin
# Tiempo transcurrido:  0.7644050121307373
# prediccion de ruido:  tf.Tensor([[0.11238387]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 197... Fin
# Tiempo transcurrido:  0.7800049781799316
# prediccion de ruido:  tf.Tensor([[0.15088841]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 198... Fin
# Tiempo transcurrido:  0.7644047737121582
# prediccion de ruido:  tf.Tensor([[0.2719437]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 199... Fin
# Tiempo transcurrido:  0.7800052165985107
# prediccion de ruido:  tf.Tensor([[0.27691615]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 200... Fin
# Tiempo transcurrido:  0.8892054557800293
# prediccion de ruido:  tf.Tensor([[0.11515906]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 201... Fin
# Tiempo transcurrido:  0.7644050121307373
# prediccion de ruido:  tf.Tensor([[0.17034528]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 202... Fin
# Tiempo transcurrido:  0.795604944229126
# prediccion de ruido:  tf.Tensor([[0.38122055]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 203... Fin
# Tiempo transcurrido:  0.7644050121307373
# prediccion de ruido:  tf.Tensor([[0.39851582]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 204... Fin
# Tiempo transcurrido:  0.7956054210662842
# prediccion de ruido:  tf.Tensor([[0.20504853]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 205... Fin
# Tiempo transcurrido:  0.7800047397613525
# prediccion de ruido:  tf.Tensor([[0.3116262]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 206... Fin
# Tiempo transcurrido:  0.7800052165985107
# prediccion de ruido:  tf.Tensor([[0.5160465]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 207... Fin
# Tiempo transcurrido:  0.7644045352935791
# prediccion de ruido:  tf.Tensor([[0.22743878]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 208... Fin
# Tiempo transcurrido:  0.7800052165985107
# prediccion de ruido:  tf.Tensor([[0.2152735]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 209... Fin
# Tiempo transcurrido:  0.795604944229126
# prediccion de ruido:  tf.Tensor([[0.096614]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 210... Fin
# Tiempo transcurrido:  0.7800052165985107
# prediccion de ruido:  tf.Tensor([[0.05583927]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 211... Fin
# Tiempo transcurrido:  0.7644047737121582
# prediccion de ruido:  tf.Tensor([[0.04541099]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 212... Fin
# Tiempo transcurrido:  0.7664051055908203
# prediccion de ruido:  tf.Tensor([[0.10345438]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 213... Fin
# Tiempo transcurrido:  0.7810049057006836
# prediccion de ruido:  tf.Tensor([[0.2178106]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 214... Fin
# Tiempo transcurrido:  0.7644050121307373
# prediccion de ruido:  tf.Tensor([[0.03532445]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 215... Fin
# Tiempo transcurrido:  0.7800052165985107
# prediccion de ruido:  tf.Tensor([[0.2297296]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 216... Fin
# Tiempo transcurrido:  0.796605110168457
# prediccion de ruido:  tf.Tensor([[0.2662481]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 217... Fin
# Tiempo transcurrido:  0.7674050331115723
# prediccion de ruido:  tf.Tensor([[0.13987154]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 218... Fin
# Tiempo transcurrido:  0.7956054210662842
# prediccion de ruido:  tf.Tensor([[0.11512303]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 219... Fin
# Tiempo transcurrido:  0.7800047397613525
# prediccion de ruido:  tf.Tensor([[0.03583774]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 220... Fin
# Tiempo transcurrido:  0.7644050121307373
# prediccion de ruido:  tf.Tensor([[0.19079164]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 221... Fin
# Tiempo transcurrido:  0.795604944229126
# prediccion de ruido:  tf.Tensor([[0.29714534]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 222... Fin
# Tiempo transcurrido:  0.7800052165985107
# prediccion de ruido:  tf.Tensor([[0.21439135]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 223... Fin
# Tiempo transcurrido:  0.7800047397613525
# prediccion de ruido:  tf.Tensor([[0.208101]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 224... Fin
# Tiempo transcurrido:  0.7800052165985107
# prediccion de ruido:  tf.Tensor([[0.18692067]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 225... Fin
# Tiempo transcurrido:  0.8112051486968994
# prediccion de ruido:  tf.Tensor([[0.16393957]], shape=(1, 1), dtype=float32)
# ===================================================================
# ...
# prediccion de ruido:  tf.Tensor([[0.00112212]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3162... Fin
# Tiempo transcurrido:  0.7684128284454346
# prediccion de ruido:  tf.Tensor([[0.00120753]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3163... Fin
# Tiempo transcurrido:  0.7708141803741455
# prediccion de ruido:  tf.Tensor([[0.00162464]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3164... Fin
# Tiempo transcurrido:  0.7694125175476074
# prediccion de ruido:  tf.Tensor([[7.938522e-05]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3165... Fin
# Tiempo transcurrido:  0.7696099281311035
# prediccion de ruido:  tf.Tensor([[0.01503322]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3166... Fin
# Tiempo transcurrido:  0.7680110931396484
# prediccion de ruido:  tf.Tensor([[0.01769945]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3167... Fin
# Tiempo transcurrido:  0.7538127899169922
# prediccion de ruido:  tf.Tensor([[0.00228634]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3168... Fin
# Tiempo transcurrido:  0.7690110206604004
# prediccion de ruido:  tf.Tensor([[0.00054738]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3169... Fin
# Tiempo transcurrido:  0.78501296043396
# prediccion de ruido:  tf.Tensor([[0.01024249]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3170... Fin
# Tiempo transcurrido:  0.7694125175476074
# prediccion de ruido:  tf.Tensor([[0.00800529]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3171... Fin
# Tiempo transcurrido:  0.785414457321167
# prediccion de ruido:  tf.Tensor([[0.00073248]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3172... Fin
# Tiempo transcurrido:  0.7860128879547119
# prediccion de ruido:  tf.Tensor([[0.00019342]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3173... Fin
# Tiempo transcurrido:  0.7748146057128906
# prediccion de ruido:  tf.Tensor([[0.02084431]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3174... Fin
# Tiempo transcurrido:  0.7984373569488525
# prediccion de ruido:  tf.Tensor([[0.00241426]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3175... Fin
# Tiempo transcurrido:  0.7850127220153809
# prediccion de ruido:  tf.Tensor([[0.05289444]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3176... Fin
# Tiempo transcurrido:  0.7714130878448486
# prediccion de ruido:  tf.Tensor([[0.17158657]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3177... Fin
# Tiempo transcurrido:  0.8198630809783936
# prediccion de ruido:  tf.Tensor([[0.01421398]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3178... Fin
# Tiempo transcurrido:  0.7674124240875244
# prediccion de ruido:  tf.Tensor([[0.00424114]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3179... Fin
# Tiempo transcurrido:  0.7544112205505371
# prediccion de ruido:  tf.Tensor([[0.00192916]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3180... Fin
# Tiempo transcurrido:  0.7704126834869385
# prediccion de ruido:  tf.Tensor([[0.0276162]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3181... Fin
# Tiempo transcurrido:  0.7680110931396484
# prediccion de ruido:  tf.Tensor([[6.851943e-05]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3182... Fin
# Tiempo transcurrido:  0.7718143463134766
# prediccion de ruido:  tf.Tensor([[0.01436186]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3183... Fin
# Tiempo transcurrido:  0.7684128284454346
# prediccion de ruido:  tf.Tensor([[0.00075549]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3184... Fin
# Tiempo transcurrido:  0.7858157157897949
# prediccion de ruido:  tf.Tensor([[0.03205135]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3185... Fin
# Tiempo transcurrido:  0.7680110931396484
# prediccion de ruido:  tf.Tensor([[0.00176841]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3186... Fin
# Tiempo transcurrido:  0.7694125175476074
# prediccion de ruido:  tf.Tensor([[0.00048393]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3187... Fin
# Tiempo transcurrido:  0.7694129943847656
# prediccion de ruido:  tf.Tensor([[0.00027782]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3188... Fin
# Tiempo transcurrido:  0.7840123176574707
# prediccion de ruido:  tf.Tensor([[0.00110844]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3189... Fin
# Tiempo transcurrido:  0.7558128833770752
# prediccion de ruido:  tf.Tensor([[0.02054513]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3190... Fin
# Tiempo transcurrido:  0.7846114635467529
# prediccion de ruido:  tf.Tensor([[0.00258964]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3191... Fin
# Tiempo transcurrido:  0.7708141803741455
# prediccion de ruido:  tf.Tensor([[0.0093284]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3192... Fin
# Tiempo transcurrido:  0.7694127559661865
# prediccion de ruido:  tf.Tensor([[0.00659913]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3193... Fin
# Tiempo transcurrido:  0.7684125900268555
# prediccion de ruido:  tf.Tensor([[0.00682262]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3194... Fin
# Tiempo transcurrido:  0.7718143463134766
# prediccion de ruido:  tf.Tensor([[0.00193197]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3195... Fin
# Tiempo transcurrido:  0.7700188159942627
# prediccion de ruido:  tf.Tensor([[0.00147742]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3196... Fin
# Tiempo transcurrido:  0.7670106887817383
# prediccion de ruido:  tf.Tensor([[0.00328708]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3197... Fin
# Tiempo transcurrido:  0.7694129943847656
# prediccion de ruido:  tf.Tensor([[6.912892e-05]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3198... Fin
# Tiempo transcurrido:  0.754213809967041
# prediccion de ruido:  tf.Tensor([[0.00345406]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3199... Fin
# Tiempo transcurrido:  0.7690112590789795
# prediccion de ruido:  tf.Tensor([[9.248425e-05]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3200... Fin
# Tiempo transcurrido:  1.0370159149169922
# prediccion de ruido:  tf.Tensor([[0.00623253]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3201... Fin
# Tiempo transcurrido:  0.7750556468963623
# prediccion de ruido:  tf.Tensor([[0.00318769]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3202... Fin
# Tiempo transcurrido:  0.8686709403991699
# prediccion de ruido:  tf.Tensor([[0.00121254]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3203... Fin
# Tiempo transcurrido:  0.8156366348266602
# prediccion de ruido:  tf.Tensor([[0.0116877]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3204... Fin
# Tiempo transcurrido:  0.7728288173675537
# prediccion de ruido:  tf.Tensor([[0.00074559]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3205... Fin
# Tiempo transcurrido:  0.8152639865875244
# prediccion de ruido:  tf.Tensor([[0.0028058]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3206... Fin
# Tiempo transcurrido:  0.7998173236846924
# prediccion de ruido:  tf.Tensor([[0.0055182]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3207... Fin
# Tiempo transcurrido:  0.8060150146484375
# prediccion de ruido:  tf.Tensor([[0.00199127]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3208... Fin
# Tiempo transcurrido:  0.7718143463134766
# prediccion de ruido:  tf.Tensor([[6.0166592e-05]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3209... Fin
# Tiempo transcurrido:  0.7810125350952148
# prediccion de ruido:  tf.Tensor([[0.00765243]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3210... Fin
# Tiempo transcurrido:  0.774442195892334
# prediccion de ruido:  tf.Tensor([[0.00131604]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3211... Fin
# Tiempo transcurrido:  0.8444712162017822
# prediccion de ruido:  tf.Tensor([[0.00041947]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3212... Fin
# Tiempo transcurrido:  0.8406753540039062
# prediccion de ruido:  tf.Tensor([[0.00062206]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3213... Fin
# Tiempo transcurrido:  0.8860886096954346
# prediccion de ruido:  tf.Tensor([[0.00049314]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3214... Fin
# Tiempo transcurrido:  0.7900278568267822
# prediccion de ruido:  tf.Tensor([[0.00112581]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3215... Fin
# Tiempo transcurrido:  0.8350834846496582
# prediccion de ruido:  tf.Tensor([[0.00018999]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3216... Fin
# Tiempo transcurrido:  0.8186731338500977
# prediccion de ruido:  tf.Tensor([[3.535194e-05]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3217... Fin
# Tiempo transcurrido:  0.8500847816467285
# prediccion de ruido:  tf.Tensor([[0.03304324]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3218... Fin
# Tiempo transcurrido:  0.7854583263397217
# prediccion de ruido:  tf.Tensor([[6.0753846e-05]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3219... Fin
# Tiempo transcurrido:  0.7912249565124512
# prediccion de ruido:  tf.Tensor([[0.00416204]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3220... Fin
# Tiempo transcurrido:  0.7712743282318115
# prediccion de ruido:  tf.Tensor([[0.00038752]], shape=(1, 1), dtype=float32)
# ===================================================================
# Comenzando Epoca 3221.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6960\993228233.py in <module>
#      27     #dError_falsas = discriminador.train_on_batch(batch_falsas, np.zeros(TAM_LOTE))
#      28
# ---> 29     dError = discriminador.train_on_batch(batch, valores)
#      30
#      31     error_d_acumulado = np.append(error_d_acumulado, dError)
#
# ~\tf\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1854                                                     class_weight)
#    1855       self.train_function = self.make_train_function()
# -> 1856       logs = self.train_function(iterator)
#    1857
#    1858     if reset_metrics:
#
# ~\tf\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\tf\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~\tf\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# ~\tf\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# ~\tf\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# ~\tf\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
import seaborn as sns

t = np.linspace(1, len(prediccion_falsa), len(prediccion_falsa))

plt.figure(figsize=(20, 6))
plt.ylim(0, 1)
sns.lineplot(x=t, y=prediccion_falsa)
#sns.lineplot(x=t, y=error_acumulado_batch_reales, label="batch_reales", linewidth=3)
#sns.lineplot(x=t, y=error_acumulado_gError, label="gError", linewidth=3)
# Out:
# <AxesSubplot:>

# %%
t = np.linspace(1, len(error_d_acumulado), len(error_d_acumulado))

plt.figure(figsize=(20, 6))
plt.ylim(0.15, 0.3)
sns.lineplot(x=t, y=error_d_acumulado)
# Out:
# <AxesSubplot:>

# %%
ruido = np.random.normal(0,1,TAM_ENTRADA)
ruido =np.array([ruido])

resultado = generador.predict(ruido)

print(discriminador(resultado))


resultado = resultado.reshape(TAM_IMG,TAM_IMG,3)

visualizar_imagen(resultado)
# Out:
# tf.Tensor([[0.00055325]], shape=(1, 1), dtype=float32)

# %% [markdown]
# Al unificar los batch antes de entrenar se logra que el modelo empiece a aprender algo. Antes, al estar separados, el modelo aprendia a identificar las imagenes reales para luego borrar lo aprendido con las imagenes falsas, por ello no se llegaba a nada
#
# El modelo pasa de generar una silueta a nada especifico de forma ciclica, hay que modificar los parametros de aprendizaje a ver si se logra mejorar
